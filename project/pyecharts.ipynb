# %%
from pyecharts.globals import CurrentConfig,NotebookType
CurrentConfig.NOTEBOOK_TYPE=NotebookType.JUPYTER_NOTEBOOK
from pyecharts.charts import Bar
from pyecharts import options as opts
import pymysql

db = pymysql.connect(host='localhost', user='root',password='Passwd1!',port=3306,db='spark')
cursor = db.cursor()
sql = 'select * from Amazon_ReviewsTop15 limit 100'
cursor.execute(sql)
data = cursor.fetchall()
x, y =[], []
for i in data:
    x.append(i[0])
    y.append(i[1])    

def bar() -> Bar:
    c = (
    Bar()
        .add_xaxis(x)
        .add_yaxis("数量", y,category_gap="50%",gap='180%')   # category_gap柱体宽度
      #.reversal_axis()      # 旋转坐标轴
        .set_global_opts(
            opts.TitleOpts(title="图书数量分析",subtitle="前15图书数据",pos_left='center'),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=True,pos_left='25%'),       
            xaxis_opts=opts.AxisOpts(name="图书名称",axislabel_opts={"interval":0,"rotate":0}), 
            yaxis_opts=opts.AxisOpts(name="数量"),
            datazoom_opts=opts.DataZoomOpts()    #设置滑块
            )
            .set_series_opts(label_opts=opts.LabelOpts(is_show=False),
                    markpoint_opts=opts.MarkPointOpts(
                        data=[
                            opts.MarkLineItem(type_="min", name="最小值"),
                            opts.MarkLineItem(type_="max", name="最大值"),
                            opts.MarkLineItem(type_="average", name="平均值")])
                    
    )
        
    )
    return c

bar().load_javascript()
bar().render("条形图.html")
bar().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c3614f49c8d04af399e15b83172afa5f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c3614f49c8d04af399e15b83172afa5f = echarts.init(
#                     document.getElementById('c3614f49c8d04af399e15b83172afa5f'), 'white', {renderer: 'canvas'});
#                 var option_c3614f49c8d04af399e15b83172afa5f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 278329,
#                 210419,
#                 178011,
#                 176545,
#                 171813,
#                 158892,
#                 148365,
#                 146152,
#                 145958,
#                 139848,
#                 136822,
#                 125005,
#                 122266,
#                 117456,
#                 108125,
#                 98576,
#                 90564,
#                 87841,
#                 86615,
#                 85800,
#                 79470,
#                 78190,
#                 72696,
#                 70535,
#                 70190,
#                 67688,
#                 67482,
#                 63787,
#                 60961,
#                 60366,
#                 58704,
#                 57458,
#                 57324,
#                 57302,
#                 55484,
#                 52236,
#                 51496,
#                 51475,
#                 51114,
#                 50970,
#                 47696,
#                 46716,
#                 46296,
#                 46094,
#                 45969,
#                 45621,
#                 45072,
#                 44512,
#                 44169,
#                 44058,
#                 43688,
#                 39459,
#                 39440,
#                 37226,
#                 35799,
#                 35368,
#                 34848,
#                 33286,
#                 32378,
#                 31558,
#                 31052,
#                 29442,
#                 29385,
#                 28997,
#                 28688,
#                 27867,
#                 27536,
#                 27232,
#                 26766,
#                 26511,
#                 26122,
#                 25706,
#                 23626,
#                 22524,
#                 22068,
#                 21930,
#                 21640,
#                 21442,
#                 21424,
#                 21229,
#                 20140,
#                 20018,
#                 19699,
#                 19568,
#                 18979,
#                 18668,
#                 17350,
#                 17044,
#                 16782,
#                 16626,
#                 16244,
#                 16162,
#                 16035,
#                 15921,
#                 15604,
#                 14994,
#                 14792,
#                 14779,
#                 14736,
#                 14076
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "50%",
#             "barGap": "180%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u6570\u91cf": true
#             },
#             "show": true,
#             "left": "25%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "name": "\u56fe\u4e66\u540d\u79f0",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Suzanne Collins",
#                 "John Green",
#                 "E L James",
#                 "Dr. Seuss",
#                 "Gillian Flynn",
#                 "Paula Hawkins",
#                 "Laura Hillenbrand",
#                 "Harper Lee",
#                 "Gary Chapman",
#                 "Don Miguel Ruiz",
#                 "Eric Carle",
#                 "Dale Carnegie",
#                 "Michelle Obama",
#                 "Sarah Young",
#                 "R. J. Palacio",
#                 "Kristin Hannah",
#                 "Marie Kond\u014d",
#                 "Delia Owens",
#                 "Roger Priddy",
#                 "American Psychological Association",
#                 "Mark Manson",
#                 "Veronica Roth",
#                 "Anthony Doerr",
#                 "J.K. Rowling",
#                 "Giles Andreae",
#                 "Donna Tartt",
#                 "Jeff Kinney",
#                 "Bill O'Reilly",
#                 "John Grisham",
#                 "Craig Smith",
#                 "Rupi Kaur",
#                 "Tara Westover",
#                 "Jen Sincero",
#                 "Dan Brown",
#                 "Kathryn Stockett",
#                 "Rachel Hollis",
#                 "Dav Pilkey",
#                 "Stephen R. Covey",
#                 "Stieg Larsson",
#                 "Wizards RPG Team",
#                 "Fredrik Backman",
#                 "Daniel James Brown

# %%
from pyecharts.globals import CurrentConfig,NotebookType
CurrentConfig.NOTEBOOK_TYPE=NotebookType.JUPYTER_NOTEBOOK
from pyecharts.charts import Bar
from pyecharts import options as opts
import pymysql

db = pymysql.connect(host='localhost', user='root',password='Passwd1!',port=3306,db='spark')
cursor = db.cursor()
sql = 'select * from Rating_counts order by "User Rating" +0 ASC'
cursor.execute(sql)
data = cursor.fetchall()
data
# Out:
# ((4.7, 108),
#  (4.6, 105),
#  (4.8, 127),
#  (4.4, 38),
#  (4.5, 60),
#  (3.9, 3),
#  (4.3, 25),
#  (4.2, 8),
#  (4.9, 52),
#  (3.8, 2),
#  (3.6, 1),
#  (4.0, 14),
#  (4.1, 6),
#  (3.3, 1))
